# %%
import requests
from dotenv import load_dotenv
import os
import rasterio
import matplotlib.pyplot as plt

# %%
# area:
# <gml:pos>441000 6049000</gml:pos> (lower left)
# <gml:pos>894000 6403000</gml:pos> (upper right)
DATAFORSYNINGEN_LIMIT = (441000, 6049000, 894000, 6403000)
load_dotenv()

url = "https://api.dataforsyningen.dk/dhm_wcs_DAF"
params = {
    "service": "WCS",
    "version": "1.0.0",
    "request": "GetCoverage",
    "coverage": "dhm_overflade",
    "crs": "EPSG:25832",
    "bbox": str.join(",", map(str, DATAFORSYNINGEN_LIMIT)),
    "width": "512",
    "height": "512",
    "format": "GTiff",
    "token": os.getenv("DATATOKEN")
}
load_dotenv()
response = requests.get(url, params=params)

with open("dem_tile.tif", "wb") as f:
    f.write(response.content)

print("Saved dem_tile.tif")
# Out:
# Saved dem_tile.tif

# %%
with rasterio.open("dem_tile.tif") as src:
    dem = src.read(1)
    print(dem.shape)
    print(dem.min(), dem.max())
# Out:
# (512, 512)
# -5.906599 167.68188

# %%
plt.figure(figsize=(8, 6))
plt.imshow(dem, cmap="terrain")
plt.colorbar(label="Elevation (m)")
plt.title("DEM")
plt.show()

# %%
# area:
# <gml:pos>441000 6049000</gml:pos> (lower left)
# <gml:pos>894000 6403000</gml:pos> (upper right)
load_dotenv()

url = "https://api.dataforsyningen.dk/dhm_wcs_DAF"
params = {
    "service": "WCS",
    "version": "1.0.0",
    "request": "GetCoverage",
    "coverage": "dhm_overflade",
    "crs": "EPSG:25832",
    "bbox": "441000,6070000,620000,6403000",
    "width": "480",
    "height": "720",
    "format": "GTiff",
    "token": os.getenv("DATATOKEN")
}
load_dotenv()
response = requests.get(url, params=params)

with open("dem_tile.tif", "wb") as f:
    f.write(response.content)

print("Saved dem_tile.tif")
# Out:
# Saved dem_tile.tif

# %%
with rasterio.open("dem_tile.tif") as src:
    dem = src.read(1)
    print(dem.shape)
    print(dem.min(), dem.max())
# Out:
# (720, 480)
# -4.1799335 181.25229

# %%
plt.figure(figsize=(8, 6))
plt.imshow(dem, cmap="terrain")
plt.colorbar(label="Elevation (m)")
plt.title("DEM")
plt.show()

# %%
# area:
# <gml:pos>441000 6049000</gml:pos> (lower left)
# <gml:pos>894000 6403000</gml:pos> (upper right)
load_dotenv()

url = "https://api.dataforsyningen.dk/dhm_wcs_DAF"
params = {
    "service": "WCS",
    "version": "1.0.0",
    "request": "GetCoverage",
    "coverage": "dhm_overflade",
    "crs": "EPSG:25832",
    "bbox": "500000,6175000,550000,6225000",
    "width": "512",
    "height": "512",
    "format": "GTiff",
    "token": os.getenv("DATATOKEN")
}
load_dotenv()
response = requests.get(url, params=params)

with open("dem_tile.tif", "wb") as f:
    f.write(response.content)

print("Saved dem_tile.tif")
# Out:
# Saved dem_tile.tif

# %%
with rasterio.open("dem_tile.tif") as src:
    dem = src.read(1)
    print(dem.shape)
    print(dem.min(), dem.max())
# Out:
# (512, 512)
# 1.3278869 194.49556

# %%
plt.figure(figsize=(8, 6))
plt.imshow(dem, cmap="terrain")
plt.colorbar(label="Elevation (m)")
plt.title("DEM")
plt.show()
